# %% [markdown]
# # OmegaSports Validation Lab - Getting Started
#
# Welcome to the OmegaSports Validation Lab! This notebook will guide you through the basics.
#
# ## Setup Check

# %%
import sys
from pathlib import Path

# Add project root to path
project_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(project_root))

print(f'Project root: {project_root}')

# %%
# Test imports
try:
    from utils.config import LabConfig
    config = LabConfig()
    print('✓ LabConfig loaded successfully')
    print(f'  Data directory: {config.data_dir}')
except Exception as e:
    print(f'✗ Error loading LabConfig: {e}')

# %%
# Test core modules
from core.data_pipeline import DataPipeline
from core.simulation_framework import SimulationFramework
from core.performance_tracker import PerformanceTracker
from core.experiment_logger import ExperimentLogger

print('✓ All core modules imported successfully')

# %% [markdown]
# ## Next Steps
#
# 1. Read the [README.md](../README.md) for project overview
# 2. Review [ARCHITECTURE.md](../ARCHITECTURE.md) for system design
# 3. Check [INSTALLATION.md](../INSTALLATION.md) for setup help
# 4. Run the first experimental module: `Module 1: Edge Threshold Calibration`
# 5. Explore the results in the `data/experiments/` directory
